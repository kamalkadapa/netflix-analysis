# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("customer_data.csv")
df
# Out:
#       Customer ID  Age  Gender  Purchase Amount (USD)        Location Size  \
# 0            2701   22  Female                   68.0      California   XL
# 1             521   51    Male                   84.0  South Carolina    M
# 2            3157   18  Female                   50.0         Montana    M
# 3            1687   22    Male                   75.0        Illinois    L
# 4            2929   40  Female                   80.0         Alabama    L
# ...           ...  ...     ...                    ...             ...  ...
# 5045          913   24    Male                   56.0        Arkansas    M
# 5046         3466   19  Female                   53.0            Iowa    M
# 5047         3572   70  Female                   27.0    North Dakota    M
# 5048         3195   43  Female                   52.0        Maryland    L
# 5049         1832   62    Male                   71.0           Maine    M
#
#        Color  Season  Review Rating Subscription Status Discount Applied  \
# 0      Olive  Winter            3.2                  No               No
# 1      White  Spring            3.9                 Yes              Yes
# 2      Black  Winter            3.1                  No               No
# 3        Red    Fall            4.2                  No               No
# 4     Yellow  Spring            3.6                  No               No
# ...      ...     ...            ...                 ...              ...
# 5045   Green  Winter            3.4                 Yes              Yes
# 5046    Gold  Spring            3.4                  No               No
# 5047   White  Summer            3.2                  No               No
# 5048    Gold  Summer            4.6                  No               No
# 5049    Cyan  Summer            NaN                  No               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 0                   36.0           Cash                 Weekly
# 1                   20.0     Debit Card              Quarterly
# 2                   18.0           Cash                Monthly
# 3                   25.0           Cash               Annually
# 4                   17.0    Credit Card                 Weekly
# ...                  ...            ...                    ...
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months
#
# [5050 rows x 14 columns]

# %%
df.head()
# Out:
#    Customer ID  Age  Gender  Purchase Amount (USD)        Location Size  \
# 0         2701   22  Female                   68.0      California   XL
# 1          521   51    Male                   84.0  South Carolina    M
# 2         3157   18  Female                   50.0         Montana    M
# 3         1687   22    Male                   75.0        Illinois    L
# 4         2929   40  Female                   80.0         Alabama    L
#
#     Color  Season  Review Rating Subscription Status Discount Applied  \
# 0   Olive  Winter            3.2                  No               No
# 1   White  Spring            3.9                 Yes              Yes
# 2   Black  Winter            3.1                  No               No
# 3     Red    Fall            4.2                  No               No
# 4  Yellow  Spring            3.6                  No               No
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                36.0           Cash                 Weekly
# 1                20.0     Debit Card              Quarterly
# 2                18.0           Cash                Monthly
# 3                25.0           Cash               Annually
# 4                17.0    Credit Card                 Weekly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5050 non-null   int64
#  1   Age                     5050 non-null   int64
#  2   Gender                  5050 non-null   object
#  3   Purchase Amount (USD)   4492 non-null   float64
#  4   Location                5050 non-null   object
#  5   Size                    4676 non-null   object
#  6   Color                   5050 non-null   object
#  7   Season                  5050 non-null   object
#  8   Review Rating           4448 non-null   float64
#  9   Subscription Status     5050 non-null   object
#  10  Discount Applied        5048 non-null   object
#  11  Previous Purchases      4502 non-null   float64
#  12  Payment Method          5050 non-null   object
#  13  Frequency of Purchases  5050 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 552.5+ KB

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  5050.000000  5050.000000            4492.000000    4448.000000
# mean   2519.570891    44.150495             144.805203       3.668278
# std    1470.402964    15.282328             275.644944       0.865436
# min       1.000000    18.000000              10.120000       1.000000
# 25%    1252.250000    31.000000              41.000000       3.000000
# 50%    2499.500000    44.000000              65.000000       3.700000
# 75%    3740.750000    57.000000              89.000000       4.400000
# max    5099.000000    70.000000            1499.760000       5.000000
#
#        Previous Purchases
# count         4502.000000
# mean            25.221901
# std             14.521635
# min              0.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.shape
# Out:
# (5050, 14)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Purchase Amount (USD)', 'Location',
#        'Size', 'Color', 'Season', 'Review Rating', 'Subscription Status',
#        'Discount Applied', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Purchase Amount (USD)     558
# Location                    0
# Size                      374
# Color                       0
# Season                      0
# Review Rating             602
# Subscription Status         0
# Discount Applied            2
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Customer ID  Age  Gender  Purchase Amount (USD)        Location Size  \
# 0            2701   22  Female                   68.0      California   XL
# 1             521   51    Male                   84.0  South Carolina    M
# 2            3157   18  Female                   50.0         Montana    M
# 3            1687   22    Male                   75.0        Illinois    L
# 4            2929   40  Female                   80.0         Alabama    L
# ...           ...  ...     ...                    ...             ...  ...
# 5045          913   24    Male                   56.0        Arkansas    M
# 5046         3466   19  Female                   53.0            Iowa    M
# 5047         3572   70  Female                   27.0    North Dakota    M
# 5048         3195   43  Female                   52.0        Maryland    L
# 5049         1832   62    Male                   71.0           Maine    M
#
#        Color  Season  Review Rating Subscription Status Discount Applied  \
# 0      Olive  Winter            3.2                  No               No
# 1      White  Spring            3.9                 Yes              Yes
# 2      Black  Winter            3.1                  No               No
# 3        Red    Fall            4.2                  No               No
# 4     Yellow  Spring            3.6                  No               No
# ...      ...     ...            ...                 ...              ...
# 5045   Green  Winter            3.4                 Yes              Yes
# 5046    Gold  Spring            3.4                  No               No
# 5047   White  Summer            3.2                  No               No
# 5048    Gold  Summer            4.6                  No               No
# 5049    Cyan  Summer            NaN                  No               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 0                   36.0           Cash                 Weekly
# 1                   20.0     Debit Card              Quarterly
# 2                   18.0           Cash                Monthly
# 3                   25.0           Cash               Annually
# 4                   17.0    Credit Card                 Weekly
# ...                  ...            ...                    ...
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months
#
# [5000 rows x 14 columns]

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'purchase_amount', 'location', 'size',
#        'color', 'season', 'review_rating', 'subscription_status',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
bins = [0,20,35,50,100]
labels = ["Teen","Young Adult","Adult","Senior"]
df["age_group"]=pd.cut(df["age"],bins=bins,labels=labels)
# Out:
#       customer_id  age  gender  purchase_amount        location size   color  \
# 0            2701   22  Female             68.0      California   XL   Olive
# 1             521   51    Male             84.0  South Carolina    M   White
# 2            3157   18  Female             50.0         Montana    M   Black
# 3            1687   22    Male             75.0        Illinois    L     Red
# 4            2929   40  Female             80.0         Alabama    L  Yellow
# ...           ...  ...     ...              ...             ...  ...     ...
# 5045          913   24    Male             56.0        Arkansas    M   Green
# 5046         3466   19  Female             53.0            Iowa    M    Gold
# 5047         3572   70  Female             27.0    North Dakota    M   White
# 5048         3195   43  Female             52.0        Maryland    L    Gold
# 5049         1832   62    Male             71.0           Maine    M    Cyan
#
#       season  review_rating subscription_status discount_applied  \
# 0     Winter            3.2                  No               No
# 1     Spring            3.9                 Yes              Yes
# 2     Winter            3.1                  No               No
# 3       Fall            4.2                  No               No
# 4     Spring            3.6                  No               No
# ...      ...            ...                 ...              ...
# 5045  Winter            3.4                 Yes              Yes
# 5046  Spring            3.4                  No               No
# 5047  Summer            3.2                  No               No
# 5048  Summer            4.6                  No               No
# 5049  Summer            NaN                  No               No
#
#       previous_purchases payment_method frequency_of_purchases    age_group
# 0                   36.0           Cash                 Weekly  Young Adult
# 1                   20.0     Debit Card              Quarterly       Senior
# 2                   18.0           Cash                Monthly         Teen
# 3                   25.0           Cash               Annually  Young Adult
# 4                   17.0    Credit Card                 Weekly        Adult
# ...                  ...            ...                    ...          ...
# 5045                32.0  Bank Transfer                Monthly  Young Adult
# 5046                31.0     Debit Card                 Weekly         Teen
# 5047                15.0  Bank Transfer         Every 3 Months       Senior
# 5048                10.0    Credit Card              Bi-Weekly        Adult
# 5049                 5.0  Bank Transfer         Every 3 Months       Senior
#
# [5000 rows x 15 columns]

# %%
def Purchase_category(x):
    if x<30:
        return "Low"
    elif x<70:
        return "Medium"
    else:
        return "High"

df["purchase_category"]=df["purchase_amount"].apply(Purchase_category)

# %%
df.to_csv("retail_data_cleaned.csv",index=False)
